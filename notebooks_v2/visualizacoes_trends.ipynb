# %%
import pandas as pd
import pickle as pk
import plotly.express as px
pd.set_option('float_format', '{:.3f}'.format)
pd.reset_option('^display.', silent=True)

# %%
with open('../src/depara/trends/categoria.pkl', 'rb') as arq:
    df_categorias = pk.load(arq)
    df_categorias['ID'] = df_categorias['ID'].astype('int32')
    df_categorias['NOME_CATEGORIA'] = df_categorias['NOME_CATEGORIA'].astype('string')
df_categorias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              31 non-null     int32
#  1   NOME_CATEGORIA  31 non-null     string
# dtypes: int32(1), string(1)
# memory usage: 500.0 bytes

# %%
opcoes_categoria = []
for chave, linha in df_categorias.iterrows():
    dic_opcoes = {
        'label': linha['NOME_CATEGORIA'],
        'value': linha['ID']
    }
    opcoes_categoria.append(dic_opcoes)
opcoes_categoria
# Out:
# [{'label': 'Film & Animation', 'value': 1},
#  {'label': 'Autos & Vehicles', 'value': 2},
#  {'label': 'Music', 'value': 10},
#  {'label': 'Pets & Animals', 'value': 15},
#  {'label': 'Sports', 'value': 17},
#  {'label': 'Short Movies', 'value': 18},
#  {'label': 'Travel & Events', 'value': 19},
#  {'label': 'Gaming', 'value': 20},
#  {'label': 'Videoblogging', 'value': 21},
#  {'label': 'People & Blogs', 'value': 22},
#  {'label': 'Comedy', 'value': 23},
#  {'label': 'Entertainment', 'value': 24},
#  {'label': 'News & Politics', 'value': 25},
#  {'label': 'Howto & Style', 'value': 26},
#  {'label': 'Education', 'value': 27},
#  {'label': 'Science & Technology', 'value': 28},
#  {'label': 'Movies', 'value': 30},
#  {'label': 'Anime/Animation', 'value': 31},
#  {'label': 'Action/Adventure', 'value': 32},
#  {'label': 'Classics', 'value': 33},
#  {'label': 'Comedy', 'value': 34},
#  {'label': 'Documentary', 'value': 35},
#  {'label': 'Drama', 'value': 36},
#  {'label': 'Family', 'value': 37},
#  {'label': 'Foreign', 'value': 38},
#  {'label': 'Horror', 'value': 39},
#  {'label': 'Sci-Fi/Fantasy', 'value': 40},
#  {'label': 'Thriller', 'value': 41},
#  {'label': 'Shorts', 'value': 42},
#  {'label': 'Shows', 'value': 43},
#  {'label': 'Trailers', 'value': 44}]

# %%
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet')

# %%
base_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4400 entries, 0 to 4399
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_extracao          4400 non-null   string
#  1   DATA_PUBLICACAO        4400 non-null   string
#  2   ID_CANAL               4400 non-null   string
#  3   NM_CANAL               4400 non-null   string
#  4   ID_CATEGORIA           4400 non-null   int32
#  5   ID_VIDEO               4400 non-null   string
#  6   TITULO_VIDEO           4400 non-null   string
#  7   DESCRICAO              4400 non-null   string
#  8   TAGS                   3661 non-null   string
#  9   DURACAO_VIDEOS         4400 non-null   object
#  10  TOTAL_VISUALIZACOES    4400 non-null   int32
#  11  TOTAL_LIKES            4400 non-null   int32
#  12  TOTAL_FAVORITOS        4400 non-null   int32
#  13  TOTAL_COMENTARIOS      4400 non-null   int32
#  14  data_hora_extracao     4400 non-null   string
#  15  DURACAO_VIDEO_MINUTOS  4400 non-null   float32
#  16  TOTAL_CARACTERE_VIDEO  4400 non-null   int32
#  17  TOTAL_TAGS             4400 non-null   int32
#  18  HORA_EXTRACAO          4400 non-null   int32
#  19  TURNO_EXTRACAO         4400 non-null   string
#  20  INDICE_TURNO_EXTRACAO  4400 non-null   string
# dtypes: float32(1), int32(8), object(1), string(11)
# memory usage: 567.3+ KB

# %% [markdown]
# # Métricas Trends

# %% [markdown]
# - Categorias Populares por data de extração top 10

# %%
#  'TOTAL_VISUALIZACOES', 'TOTAL_LIKES', 'TOTAL_COMENTARIOS'
metrica = 'TOTAL_VISUALIZACOES'

colunas = ['data_extracao', 'ID_CATEGORIA' , 'TURNO_EXTRACAO', 'INDICE_TURNO_EXTRACAO', 'ID_VIDEO', metrica]
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet', columns=colunas)
base_trends = base_trends.query(' data_extracao == "2024-01-18" and INDICE_TURNO_EXTRACAO == "3" ')
base_trends.sort_values(by='ID_VIDEO')
# Out:
#      data_extracao  ID_CATEGORIA TURNO_EXTRACAO INDICE_TURNO_EXTRACAO  \
# 2507    2024-01-18            24          Noite                     3
# 1551    2024-01-18            17          Noite                     3
# 41      2024-01-18            17          Noite                     3
# 733     2024-01-18            24          Noite                     3
# 3672    2024-01-18            24          Noite                     3
# ...            ...           ...            ...                   ...
# 1096    2024-01-18            20          Noite                     3
# 987     2024-01-18            20          Noite                     3
# 4077    2024-01-18            17          Noite                     3
# 2590    2024-01-18            28          Noite                     3
# 3069    2024-01-18            17          Noite                     3
#
#          ID_VIDEO  TOTAL_VISUALIZACOES
# 2507  -7a68_XfpG4               679320
# 1551  -A7X9LMN0qU               114810
# 41    -JzAKMfuWy4               223287
# 733   -U5oLyhfq0A               172139
# 3672  -cGZ4mFlAFY               325350
# ...           ...                  ...
# 1096  yJzvSZ7EKN8              1451661
# 987   yN1u45QKPVw               152720
# 4077  yQPIQ97nYG4               278899
# 2590  zKmNviriS50                65072
# 3069  zQ46Lk2c4OI               440513
#
# [200 rows x 6 columns]

# %%
base_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 41 to 4357
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_extracao          200 non-null    string
#  1   ID_CATEGORIA           200 non-null    int32
#  2   TURNO_EXTRACAO         200 non-null    string
#  3   INDICE_TURNO_EXTRACAO  200 non-null    string
#  4   ID_VIDEO               200 non-null    string
#  5   TOTAL_VISUALIZACOES    200 non-null    int32
# dtypes: int32(2), string(4)
# memory usage: 9.4 KB

# %%
base_trends = base_trends.groupby(['data_extracao', 'ID_CATEGORIA']) \
    .agg(
        TOTAL_MAX=(metrica, 'sum')

    ).reset_index()

base_trends
# Out:
#    data_extracao  ID_CATEGORIA  TOTAL_MAX
# 0     2024-01-18             1     823820
# 1     2024-01-18             2     161708
# 2     2024-01-18            10   81801902
# 3     2024-01-18            17   30452063
# 4     2024-01-18            19    1074972
# 5     2024-01-18            20  124769848
# 6     2024-01-18            22   12286382
# 7     2024-01-18            23    2277480
# 8     2024-01-18            24  125759485
# 9     2024-01-18            25    5939219
# 10    2024-01-18            27     171756
# 11    2024-01-18            28    7185043

# %%
base_trends_completa = pd.merge(
    right=base_trends,
    left=df_categorias,
    how='inner',
    left_on='ID',
    right_on='ID_CATEGORIA'
).sort_values(by='TOTAL_MAX', ascending=False)
base_trends_completa
# Out:
#     ID        NOME_CATEGORIA data_extracao  ID_CATEGORIA  TOTAL_MAX
# 8   24         Entertainment    2024-01-18            24  125759485
# 5   20                Gaming    2024-01-18            20  124769848
# 2   10                 Music    2024-01-18            10   81801902
# 3   17                Sports    2024-01-18            17   30452063
# 6   22        People & Blogs    2024-01-18            22   12286382
# 11  28  Science & Technology    2024-01-18            28    7185043
# 9   25       News & Politics    2024-01-18            25    5939219
# 7   23                Comedy    2024-01-18            23    2277480
# 4   19       Travel & Events    2024-01-18            19    1074972
# 0    1      Film & Animation    2024-01-18             1     823820
# 10  27             Education    2024-01-18            27     171756
# 1    2      Autos & Vehicles    2024-01-18             2     161708

# %%
fig = px.bar(
    base_trends_completa,
    x='TOTAL_MAX',
    y='NOME_CATEGORIA',
    orientation='h',
    category_orders={'NOME_CATEGORIA': base_trends_completa['NOME_CATEGORIA'].tolist()}

)
fig.show()

# %%
base_trends_completa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 8 to 1
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              12 non-null     int32
#  1   NOME_CATEGORIA  12 non-null     string
#  2   data_extracao   12 non-null     string
#  3   ID_CATEGORIA    12 non-null     int32
#  4   TOTAL_MAX       12 non-null     int32
# dtypes: int32(3), string(2)
# memory usage: 432.0 bytes

# %% [markdown]
# - Canais populares (likes, comentarios e visualizações) Por categoria TOP 10

# %%
metrica = 'TOTAL_VISUALIZACOES'

colunas = ['data_extracao', 'ID_CATEGORIA' , 'ID_CANAL', 'NM_CANAL', 'ID_VIDEO', 'TURNO_EXTRACAO', 'INDICE_TURNO_EXTRACAO', metrica]
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet', columns=colunas)
base_trends = base_trends.query(' ID_CATEGORIA == 20 and data_extracao == "2024-01-19"  and  INDICE_TURNO_EXTRACAO == "3" ')
base_trends.sort_values(by='ID_CANAL')
# Out:
#      data_extracao  ID_CATEGORIA                  ID_CANAL  \
# 1727    2024-01-19            20  UC2t5bjwHdUX4vM2g8TRDq5g
# 2459    2024-01-19            20  UC6P6SvP2arhEdJ9Pg8qwP2A
# 2777    2024-01-19            20  UC8rAKIddyMROk00d6Kebi0g
# 2110    2024-01-19            20  UC9Qu6o04oTf-b2acahQVk1g
# 920     2024-01-19            20  UCAu_v9w-BXFtg1NAnB-JgVg
# 935     2024-01-19            20  UCAu_v9w-BXFtg1NAnB-JgVg
# 2423    2024-01-19            20  UCBiRuk3NRX_SxCsp3l3cLAw
# 2202    2024-01-19            20  UCEfGV5hx2VrXl4jOUnG0MRQ
# 806     2024-01-19            20  UCIXguhHCl8eDTkXpEuiGPUA
# 1308    2024-01-19            20  UCIXguhHCl8eDTkXpEuiGPUA
# 1004    2024-01-19            20  UCIXguhHCl8eDTkXpEuiGPUA
# 3048    2024-01-19            20  UCJIl6Ahgkfwg1DRYcg-kY3g
# 2       2024-01-19            20  UCJIl6Ahgkfwg1DRYcg-kY3g
# 34      2024-01-19            20  UCK3NkZPs0BurxabhtnSDa3g
# 969     2024-01-19            20  UCKxn56z2qU-LJi3KRgMiaUg
# 47      2024-01-19            20  UCLjzb0-xUi_gfnZGd9ZgRwQ
# 4198    2024-01-19            20  UCQEUV7le_zYKNKGmUJOwvBw
# 3729    2024-01-19            20  UCUaUhkLyJCgVOMB8YOKSN8g
# 3546    2024-01-19            20  UCUaUhkLyJCgVOMB8YOKSN8g
# 4091    2024-01-19            20  UCUouM5ZRqZoFNzUvpDeYNGQ
# 2504    2024-01-19            20  UCVse66mti9GN2SWF2eh_SCg
# 2807    2024-01-19            20  UCVse66mti9GN2SWF2eh_SCg
# 4393    2024-01-19            20  UCWKtHaeXVzUscYGcm0hEunw
# 1352    2024-01-19            20  UCWsDFcIhY2DBi3GB5uykGXA
# 3108    2024-01-19            20  UCYtaoJSk9iIrFxx8eZB15ag
# 2538    2024-01-19            20  UCYzp8-P162Em-3uZnCuGJOg
# 197     2024-01-19            20  UCa2z1-KuJYbJ5cKHD_QUDoQ
# 3394    2024-01-19            20  UCeoaBlUFa1wvkXnkYgsAY3A
# 3384    2024-01-19            20  UCeoaBlUFa1wvkXnkYgsAY3A
# 515     2024-01-19            20  UCfSCj6pb_AMSszt73mqgP_Q
# 582     2024-01-19            20  UCfSCj6pb_AMSszt73mqgP_Q
# 807     2024-01-19            20  UCfSCj6pb_AMSszt73mqgP_Q
# 2688    2024-01-19            20  UCiS882YPwZt1NfaM0gR0D9Q
# 2739    2024-01-19            20  UCiS882YPwZt1NfaM0gR0D9Q
# 1694    2024-01-19            20  UCjBp_7RuDBUYbd1LegWEJ8g
# 3734    2024-01-19            20  UCmhx7Q1WRB85e7bF-MHcehA
# 3868    2024-01-19            20  UCmhx7Q1WRB85e7bF-MHcehA
# 3025    2024-01-19            20  UCoXIbjJeb1NznRssUYw3LBQ
# 835     2024-01-19            20  UCoXIbjJeb1NznRssUYw3LBQ
# 393     2024-01-19            20  UCot9DELv0Avr0HclcekQCpg
# 3910    2024-01-19            20  UCqly9F4Fr_jf2Y1Cy5hacRg
# 2080    2024-01-19            20  UCrcBZDofBltcgGxphNia2tw
# 2037    2024-01-19            20  UCrcBZDofBltcgGxphNia2tw
# 1491    2024-01-19            20  UCrcBZDofBltcgGxphNia2tw
# 1736    2024-01-19            20  UCsTNNzGmdiiUfRJqDpl1GKw
#
#                         NM_CANAL     ID_VIDEO TURNO_EXTRACAO  \
# 1727           League of Legends  ZHhqwBwmRkI          Noite
# 2459                       Athos  RVoUKeKn7q0          Noite
# 2777        KillerProductionsful  34ei8y1vjOU          Noite
# 2110                   Kass e KR  WZMFR2HHPto          Noite
# 920                         Apuh  RApm1yPoE-0          Noite
# 935                         Apuh  g7bRCHLCs1g          Noite
# 2423                         Xou  wq0TJjlggrM          Noite
# 2202                      Geleia  xmnrb2Q6D44          Noite
# 806                    Jazzghost  yJzvSZ7EKN8          Noite
# 1308                   Jazzghost  kVzwBImBoGU          Noite
# 1004                   Jazzghost  57ywwPKMEbA          Noite
# 3048                    Mendrake  gefR3nRSq6w          Noite
# 2                       Mendrake  hQLdpblz3xQ          Noite
# 34                      Souzones  jn6kT6YBdOY          Noite
# 969                     Casimiro  yN1u45QKPVw          Noite
# 47             Richard GameVlogs  2wpznW4qAu0          Noite
# 4198                      Bauers  q_EQMwopteI          Noite
# 3729                  Play Guima  fLg9gqAV4qI          Noite
# 3546                  Play Guima  FAiNpxAadI4          Noite
# 4091              Lucas Clash ON  UdXbmiZdBX4          Noite
# 2504                     FREITAS  a8LH2l-dW1U          Noite
# 2807                     FREITAS  xNpIg_GyxrA          Noite
# 4393                     BRKsEDU  cMU4YQ3ZrbM          Noite
# 1352                  IShowSpeed  A0u8rgz4qlA          Noite
# 3108            Robin Hood Gamer  l198x4TFqSk          Noite
# 2538                 Games EduUu  GqQEKL7o7Cc          Noite
# 197                       Açúcar  wyCIS_526WE          Noite
# 3394                      GonGon  uutMq8Lgga8          Noite
# 3384                      GonGon  kDGgMTtKrdY          Noite
# 515                         Lggj  gjoxK9x9ljM          Noite
# 582                         Lggj  hqmR7qhBXOk          Noite
# 807                         Lggj  YI_1rXssqzU          Noite
# 2688              Genshin Impact  abZdO3rWoVc          Noite
# 2739              Genshin Impact  zQk1QHm2-Cw          Noite
# 1694                        Xbox  ELFSdlFmDNI          Noite
# 3734                      Ligonz  W9ihAbPHpww          Noite
# 3868                      Ligonz  O4jdx0CzVZg          Noite
# 3025                     FixzTwo  WGSVJJIu0mI          Noite
# 835                      FixzTwo  aBugQ1P5MHg          Noite
# 393           MODO CARREIRA SOTO  RYKkM4qYLVo          Noite
# 3910  Bandai Namco Entertainment  YrUtDe4wFYw          Noite
# 2080                    Propolis  skMrlmbvqdg          Noite
# 2037                    Propolis  o_MQBA2shDk          Noite
# 1491                    Propolis  CPWeiZKO-Vw          Noite
# 1736         Laboratório de Zaun  0KlQMBnOK2w          Noite
#
#      INDICE_TURNO_EXTRACAO  TOTAL_VISUALIZACOES
# 1727                     3            104889364
# 2459                     3               705586
# 2777                     3               557654
# 2110                     3               857416
# 920                      3               157753
# 935                      3               156645
# 2423                     3                72519
# 2202                     3               803370
# 806                      3              1676719
# 1308                     3              1325611
# 1004                     3              1515584
# 3048                     3               450468
# 2                        3               227752
# 34                       3               224081
# 969                      3               153907
# 47                       3               223052
# 4198                     3               256909
# 3729                     3               317885
# 3546                     3               339630
# 4091                     3               277186
# 2504                     3               679536
# 2807                     3               547154
# 4393                     3               228700
# 1352                     3              1295946
# 3108                     3               426094
# 2538                     3               668676
# 197                      3               208320
# 3394                     3               353653
# 3384                     3               354779
# 515                      3               186014
# 582                      3               182453
# 807                      3               167495
# 2688                     3               604600
# 2739                     3               572954
# 1694                     3              1071090
# 3734                     3               316972
# 3868                     3               302199
# 3025                     3               460406
# 835                      3               165444
# 393                      3               193594
# 3910                     3               298414
# 2080                     3               873795
# 2037                     3               892110
# 1491                     3              1209960
# 1736                     3               104614

# %%
base_trends_canal_top_dez = base_trends.groupby(['data_extracao', 'ID_CANAL', 'NM_CANAL']) \
    .agg(
        TOTAL_MAX=(metrica, 'sum')
    ).reset_index()

base_trends_canal_top_dez.nlargest(10, columns=['TOTAL_MAX'])
# Out:
#    data_extracao                  ID_CANAL           NM_CANAL  TOTAL_MAX
# 0     2024-01-19  UC2t5bjwHdUX4vM2g8TRDq5g  League of Legends  104889364
# 7     2024-01-19  UCIXguhHCl8eDTkXpEuiGPUA          Jazzghost    4517914
# 29    2024-01-19  UCrcBZDofBltcgGxphNia2tw           Propolis    2975865
# 17    2024-01-19  UCWsDFcIhY2DBi3GB5uykGXA         IShowSpeed    1295946
# 15    2024-01-19  UCVse66mti9GN2SWF2eh_SCg            FREITAS    1226690
# 23    2024-01-19  UCiS882YPwZt1NfaM0gR0D9Q     Genshin Impact    1177554
# 24    2024-01-19  UCjBp_7RuDBUYbd1LegWEJ8g               Xbox    1071090
# 3     2024-01-19  UC9Qu6o04oTf-b2acahQVk1g          Kass e KR     857416
# 6     2024-01-19  UCEfGV5hx2VrXl4jOUnG0MRQ             Geleia     803370
# 21    2024-01-19  UCeoaBlUFa1wvkXnkYgsAY3A             GonGon     708432

# %%
base_trends_canal_top_dez.nsmallest(10, columns=['TOTAL_MAX'])
# Out:
#    data_extracao                  ID_CANAL             NM_CANAL  TOTAL_MAX
# 5     2024-01-19  UCBiRuk3NRX_SxCsp3l3cLAw                  Xou      72519
# 30    2024-01-19  UCsTNNzGmdiiUfRJqDpl1GKw  Laboratório de Zaun     104614
# 10    2024-01-19  UCKxn56z2qU-LJi3KRgMiaUg             Casimiro     153907
# 27    2024-01-19  UCot9DELv0Avr0HclcekQCpg   MODO CARREIRA SOTO     193594
# 20    2024-01-19  UCa2z1-KuJYbJ5cKHD_QUDoQ               Açúcar     208320
# 11    2024-01-19  UCLjzb0-xUi_gfnZGd9ZgRwQ    Richard GameVlogs     223052
# 9     2024-01-19  UCK3NkZPs0BurxabhtnSDa3g             Souzones     224081
# 16    2024-01-19  UCWKtHaeXVzUscYGcm0hEunw              BRKsEDU     228700
# 12    2024-01-19  UCQEUV7le_zYKNKGmUJOwvBw               Bauers     256909
# 14    2024-01-19  UCUouM5ZRqZoFNzUvpDeYNGQ       Lucas Clash ON     277186

# %% [markdown]
# - Desempenho da categoria por dia

# %%
metrica = 'TOTAL_VISUALIZACOES'

colunas = ['data_extracao', 'ID_CATEGORIA' , 'ID_CANAL', 'NM_CANAL', 'ID_VIDEO', 'TURNO_EXTRACAO', 'INDICE_TURNO_EXTRACAO', metrica]
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet', columns=colunas)
base_trends = base_trends.query(' ID_CATEGORIA == 20 and  INDICE_TURNO_EXTRACAO == "3" ')
base_trends.sort_values(by='data_extracao')
# Out:
#      data_extracao  ID_CATEGORIA                  ID_CANAL        NM_CANAL  \
# 2887    2024-01-17            20  UCVse66mti9GN2SWF2eh_SCg         FREITAS
# 2588    2024-01-17            20  UCH2958aySlHIuMzpUE8Xe9A          Tex HS
# 1215    2024-01-17            20  UCAu_v9w-BXFtg1NAnB-JgVg            Apuh
# 1211    2024-01-17            20  UCAu_v9w-BXFtg1NAnB-JgVg            Apuh
# 1192    2024-01-17            20  UC6P6SvP2arhEdJ9Pg8qwP2A           Athos
# ...            ...           ...                       ...             ...
# 2810    2024-01-23            20  UCvp2rct896qzl9qaG20mjNg      GamerCosta
# 1990    2024-01-23            20  UCrcBZDofBltcgGxphNia2tw        Propolis
# 3170    2024-01-23            20  UCUouM5ZRqZoFNzUvpDeYNGQ  Lucas Clash ON
# 1705    2024-01-23            20  UCiS882YPwZt1NfaM0gR0D9Q  Genshin Impact
# 3452    2024-01-23            20  UCUaUhkLyJCgVOMB8YOKSN8g      Play Guima
#
#          ID_VIDEO TURNO_EXTRACAO INDICE_TURNO_EXTRACAO  TOTAL_VISUALIZACOES
# 2887  xNpIg_GyxrA          Noite                     3               521975
# 2588  YTLiUbSMK1o          Noite                     3               651193
# 1215  RApm1yPoE-0          Noite                     3               138432
# 1211  RApm1yPoE-0          Noite                     3               138621
# 1192  gy_sxyoMwhE          Noite                     3              1397335
# ...           ...            ...                   ...                  ...
# 2810  oYiey5uDcwI          Noite                     3               545693
# 1990  skMrlmbvqdg          Noite                     3               915612
# 3170  UdXbmiZdBX4          Noite                     3               401292
# 1705  zQk1QHm2-Cw          Noite                     3              1059536
# 3452  FAiNpxAadI4          Noite                     3               347911
#
# [354 rows x 8 columns]

# %%
base_trends = base_trends.groupby(['data_extracao']) \
    .agg(
        TOTAL_MAX=(metrica, 'sum')
    ).reset_index().sort_values(by='data_extracao')

# %%
base_trends
# Out:
#   data_extracao  TOTAL_MAX
# 0    2024-01-17  248129261
# 1    2024-01-18  124769848
# 2    2024-01-19  127554063
# 3    2024-01-20  130299289
# 4    2024-01-21  130388361
# 5    2024-01-22   23721598
# 6    2024-01-23   23290214

# %%
base_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   data_extracao  7 non-null      string
#  1   TOTAL_MAX      7 non-null      int32
# dtypes: int32(1), string(1)
# memory usage: 212.0 bytes

# %% [markdown]
# - Top 10 vídeo em alta por categoria  selecionando dia

# %%
metrica = 'TOTAL_VISUALIZACOES'

colunas = ['data_extracao', 'ID_CATEGORIA' , 'TURNO_EXTRACAO', 'INDICE_TURNO_EXTRACAO', 'ID_VIDEO', 'TITULO_VIDEO', metrica]
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet', columns=colunas)
base_trends = base_trends.query(' data_extracao == "2024-01-20" and INDICE_TURNO_EXTRACAO == "3" and ID_CATEGORIA == 20')
base_trends.sort_values(by='ID_VIDEO')
# Out:
#      data_extracao  ID_CATEGORIA TURNO_EXTRACAO INDICE_TURNO_EXTRACAO  \
# 1719    2024-01-20            20          Noite                     3
# 4397    2024-01-20            20          Noite                     3
# 2715    2024-01-20            20          Noite                     3
# 809     2024-01-20            20          Noite                     3
# 359     2024-01-20            20          Noite                     3
# 895     2024-01-20            20          Noite                     3
# 1364    2024-01-20            20          Noite                     3
# 1422    2024-01-20            20          Noite                     3
# 3522    2024-01-20            20          Noite                     3
# 2464    2024-01-20            20          Noite                     3
# 3754    2024-01-20            20          Noite                     3
# 884     2024-01-20            20          Noite                     3
# 2377    2024-01-20            20          Noite                     3
# 387     2024-01-20            20          Noite                     3
# 3788    2024-01-20            20          Noite                     3
# 3653    2024-01-20            20          Noite                     3
# 2999    2024-01-20            20          Noite                     3
# 2093    2024-01-20            20          Noite                     3
# 687     2024-01-20            20          Noite                     3
# 3899    2024-01-20            20          Noite                     3
# 1715    2024-01-20            20          Noite                     3
# 2468    2024-01-20            20          Noite                     3
# 699     2024-01-20            20          Noite                     3
# 2183    2024-01-20            20          Noite                     3
# 4236    2024-01-20            20          Noite                     3
# 3703    2024-01-20            20          Noite                     3
# 522     2024-01-20            20          Noite                     3
# 2955    2024-01-20            20          Noite                     3
# 503     2024-01-20            20          Noite                     3
# 3953    2024-01-20            20          Noite                     3
# 552     2024-01-20            20          Noite                     3
# 8       2024-01-20            20          Noite                     3
# 3357    2024-01-20            20          Noite                     3
# 1244    2024-01-20            20          Noite                     3
# 3044    2024-01-20            20          Noite                     3
# 3686    2024-01-20            20          Noite                     3
# 1966    2024-01-20            20          Noite                     3
# 4140    2024-01-20            20          Noite                     3
# 2043    2024-01-20            20          Noite                     3
# 3374    2024-01-20            20          Noite                     3
# 1379    2024-01-20            20          Noite                     3
# 171     2024-01-20            20          Noite                     3
# 2763    2024-01-20            20          Noite                     3
# 2146    2024-01-20            20          Noite                     3
# 623     2024-01-20            20          Noite                     3
# 956     2024-01-20            20          Noite                     3
# 2134    2024-01-20            20          Noite                     3
#
#          ID_VIDEO                                       TITULO_VIDEO  \
# 1719  0KlQMBnOK2w  É TUDO QUE A GENTE QUERIA... REACT ANIMAÇÃO TE...
# 4397  2wpznW4qAu0  SOBREVIVI COMO SERPENTE GODZILLA DINOSSAURO 10...
# 2715  34ei8y1vjOU    O ALDEÃO FAVORITO DO GROX! | MINECRAFT | GroxMC
# 809   57ywwPKMEbA  ZEREI DEEEER SIMULATOR SÓ PRA VER 9 JAZZGHOST ...
# 359   94fChr6ID0I  MUDANÇAS NO CS E BR? NOVA TERRA 2.0? NOVO PERS...
# 895   A0u8rgz4qlA                                   Life In Brazil🇧🇷
# 1364  CPWeiZKO-Vw        Revelando os 10 Piores Segredos do PROPOLIS
# 1422  ELFSdlFmDNI                              Developer_Direct 2024
# 3522  FAiNpxAadI4            O PRÓPOLIS ̷I̷N̷V̷A̷D̷I̷U̷ MEU CANAL...
# 2464  GqQEKL7o7Cc  A VOLTA DA GALINHA ATACADA! - Chicken Feet Bre...
# 3754  O4jdx0CzVZg             EU TRANSFORMEI MINHA BASE NO MINECRAFT
# 884   RApm1yPoE-0  FINALMENTE TIVE MINHA VINGANÇA!! DIA DO EXPURG...
# 2377  RVoUKeKn7q0  CRIAMOS uma CASA SECRETA DENTRO da ILHA no Min...
# 387   RYKkM4qYLVo  Dorival promete ACABAR com a MOLEZA de MUITOS ...
# 3788  UdXbmiZdBX4  Entrei em um Servidor VIP Abandonado há 3 anos...
# 3653  W9ihAbPHpww  EU fui BANIDO do SERVIDOR, ENTÃO EU FIZ VINGAN...
# 2999  WGSVJJIu0mI                      Todos os DROPS são ALEATÓRIOS
# 2093  WZMFR2HHPto  CRIAMOS uma CASA SECRETA para se PROTEGER no M...
# 687   YI_1rXssqzU  FIZ UM BUNKER À PROVA DE DIA DO EXPURGO -  Irm...
# 3899  YrUtDe4wFYw          DRAGON BALL LEGENDS "REVEALS ＆ STUFF #33"
# 1715  ZHhqwBwmRkI  Still Here | Season 2024 Cinematic - League of...
# 2468  a8LH2l-dW1U  APELEI USANDO A RAMBÃO NIVEL 3 SOLO VS SQUAD!!...
# 699   aBugQ1P5MHg  Zerei o Minecraft só que TUDO que eu OLHO EU G...
# 2183  abZdO3rWoVc         Version 4.4 Special Program｜Genshin Impact
# 4236  cMU4YQ3ZrbM  THE LAST OF US PART II REMASTERED - Gameplay d...
# 3703  fLg9gqAV4qI                         EU FALEI COM O PRÓPOLIS...
# 522   g7bRCHLCs1g                1 BLOCO MAS CHOVE ITENS DO AVARITIA
# 2955  gefR3nRSq6w                     A UNIÃO MAIS FORTE DO SERVIDOR
# 503   gjoxK9x9ljM  A SEMANA DO EXPURGO, 168 HORAS SEM REGRAS NESS...
# 3953  hQLdpblz3xQ                               PROPOLIS vs MENDRAKE
# 552   hqmR7qhBXOk                      A GRANDE VINGANÇA - Irmandade
# 8     jn6kT6YBdOY  GOOSE GOOSE DUCK: MINHA REDENÇÃO APÓS A PIOR P...
# 3357  kDGgMTtKrdY  NOVO PASSE + NOVO EMOTE ESPECIAL + H̴̲̾̋Å̆̿̀ͬ...
# 1244  kVzwBImBoGU  24 HORAS SOBREVIVENDO EM UM MUNDO TODO FEITO D...
# 3044  l198x4TFqSk  INVADIU? DESAFIO DA BASE SEGURA VS LUFFY DO MA...
# 3686  oYiey5uDcwI           O CARRO AMALDIÇOADO DO FRANKLIN NO GTA 5
# 1966  o_MQBA2shDk            Eu Destrui os Youtubers que Você AMA...
# 4140  q_EQMwopteI         𝗢 𝗣𝗥𝗢𝗣𝗢𝗟𝗜𝗦 𝗙𝗘𝗭 𝗘𝗫𝗘𝗥𝗖𝗜𝗧𝗢 𝗗𝗘 𝗖𝗟𝗢𝗡𝗘𝗦 𝗫𝗜𝗡𝗚𝗟𝗔𝗨…
# 2043  skMrlmbvqdg                       Eu Preciso PARAR o Propolis!
# 3374  uutMq8Lgga8     DESVENDANDO A HISTÓRIA POR TRÁS DO PROPOLIS...
# 1379  wq0TJjlggrM  SAIU a MEGA ATUALIZAÇÃO do KING LEGACY!! O TER...
# 171   wyCIS_526WE         FIM DO CANAL... Propolis INVADIU meu canal
# 2763  xNpIg_GyxrA  FINALMENTE ALCANCEI A LIGA MESTRE EM UMA PARTI...
# 2146  xmnrb2Q6D44  Eu Desafiei o PRÓPOLIS pra RECUPERAR O CANAL d...
# 623   yJzvSZ7EKN8               NO MEU CAMELÔ DE JOGOS JÁ TEM GTA 6!
# 956   yN1u45QKPVw                                               BBB.
# 2134  zQk1QHm2-Cw  Version 4.4 "Vibrant Harriers Aloft in Spring ...
#
#       TOTAL_VISUALIZACOES
# 1719               105190
# 4397               228218
# 2715               588365
# 809               1673312
# 359                 19623
# 895               1609632
# 1364              1287065
# 1422              1245027
# 3522               342468
# 2464               703220
# 3754               315218
# 884                161780
# 2377               743387
# 387                193925
# 3788               310381
# 3653               327951
# 2999               470138
# 2093               867821
# 687                174389
# 3899               299625
# 1715            105324793
# 2468               702239
# 699                173700
# 2183               814854
# 4236               250253
# 3703               321379
# 522                185904
# 2955               490990
# 503                187094
# 3953               291598
# 552                184600
# 8                  226943
# 3357               358741
# 1244              1369767
# 3044               452923
# 3686               323375
# 1966               924698
# 4140               270205
# 2043               888654
# 3374               356780
# 1379               127160
# 171                210312
# 2763               563236
# 2146               837904
# 623               1794669
# 956                154786
# 2134               844997

# %%
base_trends_top_dez =  base_trends.groupby(['data_extracao', 'ID_VIDEO']) \
    .agg(
        TOTAL_MAX=(metrica, 'sum')
    ).reset_index().sort_values(by='TOTAL_MAX', ascending=False)
base_trends_top_dez.nlargest(10, columns=['TOTAL_MAX'])
# Out:
#    data_extracao     ID_VIDEO  TOTAL_MAX
# 20    2024-01-20  ZHhqwBwmRkI  105324793
# 44    2024-01-20  yJzvSZ7EKN8    1794669
# 3     2024-01-20  57ywwPKMEbA    1673312
# 5     2024-01-20  A0u8rgz4qlA    1609632
# 33    2024-01-20  kVzwBImBoGU    1369767
# 6     2024-01-20  CPWeiZKO-Vw    1287065
# 7     2024-01-20  ELFSdlFmDNI    1245027
# 36    2024-01-20  o_MQBA2shDk     924698
# 38    2024-01-20  skMrlmbvqdg     888654
# 17    2024-01-20  WZMFR2HHPto     867821

# %%
base_trends_top_dez.nsmallest(10, columns=['TOTAL_MAX'])
# Out:
#    data_extracao     ID_VIDEO  TOTAL_MAX
# 4     2024-01-20  94fChr6ID0I      19623
# 0     2024-01-20  0KlQMBnOK2w     105190
# 40    2024-01-20  wq0TJjlggrM     127160
# 45    2024-01-20  yN1u45QKPVw     154786
# 11    2024-01-20  RApm1yPoE-0     161780
# 22    2024-01-20  aBugQ1P5MHg     173700
# 18    2024-01-20  YI_1rXssqzU     174389
# 30    2024-01-20  hqmR7qhBXOk     184600
# 26    2024-01-20  g7bRCHLCs1g     185904
# 28    2024-01-20  gjoxK9x9ljM     187094

# %% [markdown]
# - Engajamento por canal Top 10 selecionando categoria e data

# %%
colunas = ['data_extracao', 'ID_CATEGORIA' , 'INDICE_TURNO_EXTRACAO', 'ID_CANAL', 'NM_CANAL', 'TITULO_VIDEO', 'TOTAL_VISUALIZACOES', 'TOTAL_LIKES', 'TOTAL_COMENTARIOS']
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet', columns=colunas)
base_trends = base_trends.query(' data_extracao == "2024-01-18" and INDICE_TURNO_EXTRACAO == "3" and ID_CATEGORIA == 20')
base_trends.head(5)
# Out:
#     data_extracao  ID_CATEGORIA INDICE_TURNO_EXTRACAO  \
# 65     2024-01-18            20                     3
# 83     2024-01-18            20                     3
# 98     2024-01-18            20                     3
# 205    2024-01-18            20                     3
# 230    2024-01-18            20                     3
#
#                      ID_CANAL            NM_CANAL  \
# 65   UCK3NkZPs0BurxabhtnSDa3g            Souzones
# 83   UCgWiuB2PQIUhJgEN9No281g  VALORANT // Brasil
# 98   UCLjzb0-xUi_gfnZGd9ZgRwQ   Richard GameVlogs
# 205  UCWKtHaeXVzUscYGcm0hEunw             BRKsEDU
# 230  UCa2z1-KuJYbJ5cKHD_QUDoQ              Açúcar
#
#                                           TITULO_VIDEO  TOTAL_VISUALIZACOES  \
# 65   GOOSE GOOSE DUCK: MINHA REDENÇÃO APÓS A PIOR P...               221033
# 83     RETALIAÇÃO // Animação do Episódio 8 – VALORANT               218942
# 98   SOBREVIVI COMO SERPENTE GODZILLA DINOSSAURO 10...               217115
# 205  THE LAST OF US PART II REMASTERED - Gameplay d...               207627
# 230         FIM DO CANAL... Propolis INVADIU meu canal               205850
#
#      TOTAL_LIKES  TOTAL_COMENTARIOS
# 65         29822                927
# 83         25402                898
# 98          5458                 80
# 205        17813                764
# 230         8014               1268

# %%
base_trends.groupby(['ID_CANAL', 'NM_CANAL']) \
    .agg(
        TOTAL_VISUALIZACOES=('TOTAL_VISUALIZACOES', 'sum'),
        TOTAL_LIKES=('TOTAL_LIKES', 'sum'),
        TOTAL_COMENTARIOS=('TOTAL_VISUALIZACOES', 'sum'),
    ).reset_index()
# Out:
#                     ID_CANAL                    NM_CANAL  TOTAL_VISUALIZACOES  \
# 0   UC2t5bjwHdUX4vM2g8TRDq5g           League of Legends            104466364
# 1   UC6P6SvP2arhEdJ9Pg8qwP2A                       Athos               661846
# 2   UC8rAKIddyMROk00d6Kebi0g        KillerProductionsful               511855
# 3   UC9Qu6o04oTf-b2acahQVk1g                   Kass e KR               848176
# 4   UCAu_v9w-BXFtg1NAnB-JgVg                        Apuh               341547
# 5   UCEfGV5hx2VrXl4jOUnG0MRQ                      Geleia               740488
# 6   UCH2958aySlHIuMzpUE8Xe9A                      Tex HS               667992
# 7   UCIXguhHCl8eDTkXpEuiGPUA                   Jazzghost              3739709
# 8   UCJIl6Ahgkfwg1DRYcg-kY3g                    Mendrake               385537
# 9   UCK3NkZPs0BurxabhtnSDa3g                    Souzones               221033
# 10  UCKxn56z2qU-LJi3KRgMiaUg                    Casimiro               152720
# 11  UCLjzb0-xUi_gfnZGd9ZgRwQ           Richard GameVlogs               217115
# 12  UCQEUV7le_zYKNKGmUJOwvBw                      Bauers               237202
# 13  UCUaUhkLyJCgVOMB8YOKSN8g                  Play Guima               647618
# 14  UCVse66mti9GN2SWF2eh_SCg                     FREITAS              1195921
# 15  UCWKtHaeXVzUscYGcm0hEunw                     BRKsEDU               207627
# 16  UCWsDFcIhY2DBi3GB5uykGXA                  IShowSpeed              2304705
# 17  UCYtaoJSk9iIrFxx8eZB15ag            Robin Hood Gamer               372874
# 18  UCYzp8-P162Em-3uZnCuGJOg                 Games EduUu               627745
# 19  UCa2z1-KuJYbJ5cKHD_QUDoQ                      Açúcar               205850
# 20  UCeoaBlUFa1wvkXnkYgsAY3A                      GonGon               698642
# 21  UCfSCj6pb_AMSszt73mqgP_Q                        Lggj               516272
# 22  UCgWiuB2PQIUhJgEN9No281g          VALORANT // Brasil               218942
# 23  UCmhx7Q1WRB85e7bF-MHcehA                      Ligonz               582912
# 24  UCoXIbjJeb1NznRssUYw3LBQ                     FixzTwo               600975
# 25  UCot9DELv0Avr0HclcekQCpg          MODO CARREIRA SOTO               193198
# 26  UCqly9F4Fr_jf2Y1Cy5hacRg  Bandai Namco Entertainment               296714
# 27  UCrcBZDofBltcgGxphNia2tw                    Propolis              2804234
# 28  UCsTNNzGmdiiUfRJqDpl1GKw         Laboratório de Zaun               104035
#
#     TOTAL_LIKES  TOTAL_COMENTARIOS
# 0       1760712          104466364
# 1         13180             661846
# 2         40956             511855
# 3         45368             848176
# 4         46853             341547
# 5         25120             740488
# 6         30495             667992
# 7        206739            3739709
# 8         18691             385537
# 9         29822             221033
# 10        12712             152720
# 11         5458             217115
# 12        11687             237202
# 13        27383             647618
# 14        94675            1195921
# 15        17813             207627
# 16       161328            2304705
# 17        13159             372874
# 18       108450             627745
# 19         8014             205850
# 20        21556             698642
# 21        52779             516272
# 22        25402             218942
# 23        22704             582912
# 24        13128             600975
# 25        21180             193198
# 26            0             296714
# 27       126548            2804234
# 28        10646             104035

# %%
base_trends['TAXA_ENGAJAMENTO'] = round(((base_trends['TOTAL_LIKES'] + base_trends['TOTAL_COMENTARIOS']) / base_trends['TOTAL_VISUALIZACOES']) * 100, 2)
base_trends_top_dez = base_trends.nlargest(10, columns=['TAXA_ENGAJAMENTO'])
base_trends_top_dez[['data_extracao', 'ID_CANAL', 'NM_CANAL','TOTAL_VISUALIZACOES' ,  'TOTAL_COMENTARIOS', 'TOTAL_LIKES', 'TAXA_ENGAJAMENTO']]
# Out:
#      data_extracao                  ID_CANAL             NM_CANAL  \
# 2642    2024-01-18  UCYzp8-P162Em-3uZnCuGJOg          Games EduUu
# 453     2024-01-18  UCAu_v9w-BXFtg1NAnB-JgVg                 Apuh
# 65      2024-01-18  UCK3NkZPs0BurxabhtnSDa3g             Souzones
# 1012    2024-01-18  UCAu_v9w-BXFtg1NAnB-JgVg                 Apuh
# 83      2024-01-18  UCgWiuB2PQIUhJgEN9No281g   VALORANT // Brasil
# 996     2024-01-18  UCfSCj6pb_AMSszt73mqgP_Q                 Lggj
# 398     2024-01-18  UCot9DELv0Avr0HclcekQCpg   MODO CARREIRA SOTO
# 1754    2024-01-18  UCsTNNzGmdiiUfRJqDpl1GKw  Laboratório de Zaun
# 624     2024-01-18  UCfSCj6pb_AMSszt73mqgP_Q                 Lggj
# 550     2024-01-18  UCfSCj6pb_AMSszt73mqgP_Q                 Lggj
#
#       TOTAL_VISUALIZACOES  TOTAL_COMENTARIOS  TOTAL_LIKES  TAXA_ENGAJAMENTO
# 2642               627745               4598       108450             18.01
# 453                190492               1243        29357             16.06
# 65                 221033                927        29822             13.91
# 1012               151055                721        17496             12.06
# 83                 218942                898        25402             12.01
# 996                152161                706        17062             11.68
# 398                193198                967        21180             11.46
# 1754               104035               1128        10646             11.32
# 624                179434               1439        18316             11.01
# 550                184677               1149        17401             10.04

# %%
base_trends['TAXA_ENGAJAMENTO'] = round(((base_trends['TOTAL_LIKES'] + base_trends['TOTAL_COMENTARIOS']) / base_trends['TOTAL_VISUALIZACOES']) * 100, 2)

# %% [markdown]
# - Engajamento do vídeo por categoria

# %%
colunas = ['data_extracao', 'ID_CATEGORIA' , 'INDICE_TURNO_EXTRACAO', 'NM_CANAL', 'ID_VIDEO',  'TITULO_VIDEO', 'TOTAL_VISUALIZACOES', 'TOTAL_LIKES', 'TOTAL_COMENTARIOS']
base_trends = pd.read_parquet('../dados/ouro/dados_tratado_estatisticas_trends.parquet', columns=colunas)
base_trends = base_trends.query(' data_extracao == "2024-01-18" and INDICE_TURNO_EXTRACAO == "3" and ID_CATEGORIA == 20')
base_trends.head(5)
# Out:
#     data_extracao  ID_CATEGORIA INDICE_TURNO_EXTRACAO            NM_CANAL  \
# 65     2024-01-18            20                     3            Souzones
# 83     2024-01-18            20                     3  VALORANT // Brasil
# 98     2024-01-18            20                     3   Richard GameVlogs
# 205    2024-01-18            20                     3             BRKsEDU
# 230    2024-01-18            20                     3              Açúcar
#
#         ID_VIDEO                                       TITULO_VIDEO  \
# 65   jn6kT6YBdOY  GOOSE GOOSE DUCK: MINHA REDENÇÃO APÓS A PIOR P...
# 83   O7BueZ5WyLs    RETALIAÇÃO // Animação do Episódio 8 – VALORANT
# 98   2wpznW4qAu0  SOBREVIVI COMO SERPENTE GODZILLA DINOSSAURO 10...
# 205  cMU4YQ3ZrbM  THE LAST OF US PART II REMASTERED - Gameplay d...
# 230  wyCIS_526WE         FIM DO CANAL... Propolis INVADIU meu canal
#
#      TOTAL_VISUALIZACOES  TOTAL_LIKES  TOTAL_COMENTARIOS
# 65                221033        29822                927
# 83                218942        25402                898
# 98                217115         5458                 80
# 205               207627        17813                764
# 230               205850         8014               1268

# %%
base_trends['TAXA_ENGAJAMENTO'] = round(((base_trends['TOTAL_LIKES'] + base_trends['TOTAL_COMENTARIOS']) / base_trends['TOTAL_VISUALIZACOES']) * 100, 2)
base_trends_top_dez = base_trends.nlargest(10, columns=['TAXA_ENGAJAMENTO'])
base_trends_top_dez[['data_extracao',  'NM_CANAL', 'ID_VIDEO', 'TITULO_VIDEO','TOTAL_VISUALIZACOES' ,  'TOTAL_COMENTARIOS', 'TOTAL_LIKES', 'TAXA_ENGAJAMENTO']]
# Out:
#      data_extracao             NM_CANAL     ID_VIDEO  \
# 2642    2024-01-18          Games EduUu  GqQEKL7o7Cc
# 453     2024-01-18                 Apuh  qcoVg6RWko8
# 65      2024-01-18             Souzones  jn6kT6YBdOY
# 1012    2024-01-18                 Apuh  RApm1yPoE-0
# 83      2024-01-18   VALORANT // Brasil  O7BueZ5WyLs
# 996     2024-01-18                 Lggj  YI_1rXssqzU
# 398     2024-01-18   MODO CARREIRA SOTO  RYKkM4qYLVo
# 1754    2024-01-18  Laboratório de Zaun  0KlQMBnOK2w
# 624     2024-01-18                 Lggj  hqmR7qhBXOk
# 550     2024-01-18                 Lggj  gjoxK9x9ljM
#
#                                            TITULO_VIDEO  TOTAL_VISUALIZACOES  \
# 2642  A VOLTA DA GALINHA ATACADA! - Chicken Feet Bre...               627745
# 453       ESSE É O FIM DO DIA DO EXPURGO... - Irmandade               190492
# 65    GOOSE GOOSE DUCK: MINHA REDENÇÃO APÓS A PIOR P...               221033
# 1012  FINALMENTE TIVE MINHA VINGANÇA!! DIA DO EXPURG...               151055
# 83      RETALIAÇÃO // Animação do Episódio 8 – VALORANT               218942
# 996   FIZ UM BUNKER À PROVA DE DIA DO EXPURGO -  Irm...               152161
# 398   Dorival promete ACABAR com a MOLEZA de MUITOS ...               193198
# 1754  É TUDO QUE A GENTE QUERIA... REACT ANIMAÇÃO TE...               104035
# 624                       A GRANDE VINGANÇA - Irmandade               179434
# 550   A SEMANA DO EXPURGO, 168 HORAS SEM REGRAS NESS...               184677
#
#       TOTAL_COMENTARIOS  TOTAL_LIKES  TAXA_ENGAJAMENTO
# 2642               4598       108450             18.01
# 453                1243        29357             16.06
# 65                  927        29822             13.91
# 1012                721        17496             12.06
# 83                  898        25402             12.01
# 996                 706        17062             11.68
# 398                 967        21180             11.46
# 1754               1128        10646             11.32
# 624                1439        18316             11.01
# 550                1149        17401             10.04
