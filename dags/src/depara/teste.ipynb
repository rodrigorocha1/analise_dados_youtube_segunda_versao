# %%
import pickle
import os
from datetime import datetime
from typing import List, Dict

# %%
global CAMINHO_BASE
CAMINHO_BASE = os.path.join(os.getcwd(), 'src', 'depara')


def obter_lista_datas() -> List[datetime.date]:
    CAMINHO_LISTA_DATA = os.path.join(CAMINHO_BASE, 'trends')
    with open(os.path.join(CAMINHO_LISTA_DATA, 'lista_datas.pkl'), 'rb') as datas:
        lista_datas = pickle.load(datas)
    return lista_datas


def obter_lista_canais():
    CAMINHO_LISTA_CANAIS = os.path.join(CAMINHO_BASE, 'outros')
    with open('outros/lista_canais_depara.pkl', 'rb') as canais:
        lista_canais = pickle.load(canais)
    return lista_canais


def obter_lista_video():
    CAMINHO_LISTA_VIDEO = os.path.join(CAMINHO_BASE, 'outros')
    with open(os.path.join(CAMINHO_LISTA_VIDEO, 'lista_video_depara.pkl'), 'rb') as canais:
        lista_canais = pickle.load(canais)
    return lista_canais

# %%
obter_lista_canais()[2]
# Out:
# {'ASSUNTO': 'assunto_cities_skylines',
#  'VALORES': [{'label': 'O Construtor', 'value': 'UCmg3_taw1BrGuo1ITlQe2hA'},
#   {'label': 'MetalBear', 'value': 'UCfY4ggUDPeecGSCNePyyVSA'},
#   {'label': 'Barbosa Cities', 'value': 'UCe9jrI0YQ5SM6h5QRZ9FZlA'},
#   {'label': 'Betospa Gaming', 'value': 'UCkXA2EoaXRFW18vrAE01BpQ'},
#   {'label': 'Lives do IVDMALUCO', 'value': 'UCn7w7H6jL0G3TNpV1v0SZRg'},
#   {'label': 'Wellington Souza', 'value': 'UCBSrzvbMoru6PsayN3Z7ZsA'},
#   {'label': 'CANAL HAND - GAME WITH MUSIC',
#    'value': 'UC7v51W2NoLFawizgcNuVBOA'},
#   {'label': 'Lives do Chratos', 'value': 'UCayiH2Y5JBEOSubqoQhufDA'},
#   {'label': 'Irmãos Cities', 'value': 'UC1mk6EtfMjxR4eEZ7C43zTQ'},
#   {'label': 'Grilo Gamer', 'value': 'UCwBN6GQiolq3EkRPYC7OTtA'},
#   {'label': 'Ganso GamePlay', 'value': 'UCp7gzkfbWE7jazP65W9ZtWg'},
#   {'label': 'Lucas gameplays brasil', 'value': 'UCOYJm7BsLV8VCkW2DC1MI5w'},
#   {'label': 'BUG CITIES', 'value': 'UCDqzBrUOm7guqqyU8eDackg'},
#   {'label': 'Canal do Void', 'value': 'UCrUcdH_bCfX77xpXHyq2fJw'},
#   {'label': 'Octopolis', 'value': 'UCCe4Be21OPPltTTIHP4lDvg'},
#   {'label': 'Canal Sala de Jogos', 'value': 'UCYEb5mbKZ5JJzN0xBuKyaig'},
#   {'label': 'Majestic', 'value': 'UCxIMGC-GmZ2pXE_jGGW2C9A'},
#   {'label': 'DILSÃO', 'value': 'UCTrNnXivZU_1-aJqn1uNANg'},
#   {'label': 'ChratosGameplay', 'value': 'UCrOH1V-FyMunBIMrKL0y0xQ'},
#   {'label': 'Simularies', 'value': 'UCDGo_s0I-2JpO3o3xlkMQVA'},
#   {'label': 'Cortes Boladao', 'value': 'UCYDluKEjFODZQueXT0pZJfg'},
#   {'label': 'Bad Influence guias de otimização ',
#    'value': 'UC8FS3_qf6F194QTYwxwFGMw'},
#   {'label': 'Kassiano', 'value': 'UCiaL33s_HVulWylA63eMXJw'},
#   {'label': 'JOGA COM WILLIAM', 'value': 'UC-N8y8IuT8B44h-IQQAmq4w'},
#   {'label': 'Rodrigo Baltar', 'value': 'UCjJUe8JYQgqOxC57jZyVsEg'},
#   {'label': 'Rodness', 'value': 'UCcT7u9KeCH6v_ReHZcUhXoA'},
#   {'label': 'Dw Play', 'value': 'UCVM5Kg0mLSmmvdmhWH9OhiA'},
#   {'label': 'SkulksGamer', 'value': 'UCVsCm0DE0N-yNMazJ01RYsg'},
#   {'label': 'O Veio Games', 'value': 'UCOe_x5ararWwWajBKbFKNkA'},
#   {'label': 'SUPREME BR', 'value': 'UCGi_mAdy_Vp1x8RaUnmViqg'},
#   {'label': 'rlkpedrom', 'value': 'UCMsbzwrSvRJoa0JhS5YcsqQ'},
#   {'label': 'Quinto Controle', 'value': 'UCNv3_KHnWEzLc3BCxYXpHFQ'},
#   {'label': 'KyoKat PC Gameplay | Benchmark',
#    'value': 'UCLAUYEY8ITQC8b47xyqybxg'},
#   {'label': 'GAC TV', 'value': 'UCEc5jA0NvvR-yJC0SISV6nw'},
#   {'label': 'Migeez', 'value': 'UCHEuAFdws9OCZPcfTBuxtCw'},
#   {'label': 'Jowgando', 'value': 'UCJYFuFymG6_6TLUxC-4YHzA'},
#   {'label': 'FUMACENTO', 'value': 'UCvf1dm1mnzIqyCQpJYbVMUA'},
#   {'label': 'Ubira', 'value': 'UCHuvObnh1-2fs6zL5nhVGtg'},
#   {'label': 'Prompt Dark', 'value': 'UCABm0SdJCoM6z0MFod7s3Lg'},
#   {'label': 'Noob Cardo', 'value': 'UCEQkAgXk_T3sDMx9YSdz-cQ'},
#   {'label': 'Pika-Pau GamePlay', 'value': 'UCIEd_yNwTVZr1JChrgYR7sw'},
#   {'label': 'Atomic2C', 'value': 'UC6ZlYmIr3sdAmDLxnx-fk0g'},
#   {'label': 'MAROTO', 'value': 'UCTrEq-s7713neJ1Td9bg0Zg'},
#   {'label': 'Game com Ciência', 'value': 'UCJHBJmrVd7ujf2eCEujukog'},
#   {'label': 'HomineK1', 'value': 'UCEfL_pp3h8Ul-LIL1C4o34w'},
#   {'label': 'TioChuckZ', 'value': 'UCaj6FB2mFZ2T9a61QtZsKPA'},
#   {'label': 'Victor No Controle', 'value': 'UCccdWOiGy2vEQKjUhNZHB_g'},
#   {'label': 'BL4D3N | Jogos de Gestão e Construção',
#    'value': 'UCIv5D2ro1owj6P7OdZ4-BiA'},
#   {'label': 'GAME TV BRASA', 'value': 'UCsi_LmcdII_1jAPSuGEjgnA'},
#   {'label': 'TTauros Gamer', 'value': 'UCmCavIluxnSwtPRLgxw3bYA'},
#   {'label': 'Cabrunco Games', 'value': 'UCcn60fs5EMW8A_k9R-e4gEg'},
#   {'label': 'Sr L', 'value': 'UCvEj9EurcC8q5hkV-Apf4jA'},
#   {'label': 'Cogumelando Videogame', 'value': 'UCXso4Ho8UARhzS3I_LOVTKA'},
#   {'label': 'TIO Joe', 'value': 'UCiRdaC8jG1-K87ciSUbT2iw'},
#   {'label': 'Skarlatus', 'value': 'UCArranHxpFguoPoOndKkdTA'},
#   {'label': 'JulioGameplay', 'value': 'UCL5k8vBBo1JOHh7AnvoD8xQ'},
#   {'label': 'Pinguires', 'value': 'UCla_gQERStTS74gxHMS6Tzw'},
#   {'label': 'UaiSô Games', 'value': 'UCC5w9Ias-S8E15hyS00Cfew'},
#   {'label': 'elvisplaylive', 'value': 'UCIMUxCvkVcuDFXzwoR8H3fQ'},
#   {'label': 'snesdioh', 'value': 'UCfkgc6FfJCP362BdVNBpZHw'},
#   {'label': 'Nicholas Games', 'value': 'UCdZK6DwemFBiKHlkez2tdUA'},
#   {'label': 'gastro games', 'value': 'UCNCMu1_0mQFX5NsB2Um4Oxg'},
#   {'label': 'LiminhaG0d', 'value': 'UCVGeMHXGFIPjzosF8SOYemA'},
#   {'label': 'InteliGame', 'value': 'UCECueo5gAX7odvuiLCjklbA'},
#   {'label': 'LukeTuke', 'value': 'UCrlUvYytIVrkoIZuvy9DF0A'},
#   {'label': 'Jogando', 'value': 'UCGved3ynk6ZhUvSKxzgweTw'},
#   {'label': 'Taverna Replicante', 'value': 'UClGA2euv_zdZ442GcVBjcbg'},
#   {'label': 'Douglas Willian YT', 'value': 'UCVM5Kg0mLSmmvdmhWH9OhiA'},
#   {'label': 'PLAYER 7', 'value': 'UCu3zxvlrYc6dYM3102Y5Y9g'},
#   {'label': 'CENTRAL', 'value': 'UCoTIpyf8_RGzJ1LPTmvadaA'},
#   {'label': 'Personal Apple VR', 'value': 'UCfuxXVeeaS8cLj2kxcvOdYw'},
#   {'label': 'Patife', 'value': 'UCC6ayGbvqQ6R63aoz95ovuA'},
#   {'label': 'Bruuninz', 'value': 'UCoBbeu5bEvrJJDCCRSQJb4Q'},
#   {'label': 'Team Random', 'value': 'UCRt5pfs_8hq3-GUSjULoV9Q'},
#   {'label': 'Mundo Gamer TV', 'value': 'UC44qgwxGNPbfaAGQV1K6kVg'},
#   {'label': 'HughesGames', 'value': 'UCrhZH-oxUpmnZRISf8Xw7rQ'},
#   {'label': 'MONTE', 'value': 'UColWqaBtRa6AEyDen2h5lRg'},
#   {'label': 'ViktorKav', 'value': 'UCS4vJlnzDYiPA7iWQI65IQw'},
#   {'label': 'mkjxzz', 'value': 'UCt0IBPkhrVM43xSyP2vCnAw'},
#   {'label': 'Wilhaco', 'value': 'UC7VsdBUkBvIBMRP7CU45XMA'},
#   {'label': 'skzkkj', 'value': 'UCe2Mg0JDkzq_qxMHYZg_sOg'},
#   {'label': 'Le Alves Play', 'value': 'UCT1DmITSbFv3tN5GqalE-mg'},
#   {'label': 'Rivas', 'value': 'UCD9YHClUr3tSoAm-kj8ejDA'},
#   {'label': 'Dannoob', 'value': 'UCxtXKH7HqVxD5EOJKfMxCDw'},
#   {'label': 'Gabriel Boeni', 'value': 'UCA6PcJz0-vfOmnZhM5TirVQ'},
#   {'label': 'GalileZinski', 'value': 'UC_a5ykpZR8o-5exRDYCFp0Q'},
#   {'label': 'Dinas e Games', 'value': 'UCU1xEpdwRITwjZ0vnUxzYaw'},
#   {'label': 'silva tweaks', 'value': 'UCJ_PUBiy-NwJ-woO18z330Q'},
#   {'label': 'Fumacinha', 'value': 'UCHm9aiQsllQbGcxu4ynJCAA'},
#   {'label': 'Klyte45', 'value': 'UCElNoZcxhVqDtZBSrdEomnA'},
#   {'label': 'Luh Gamer', 'value': 'UCocGh-G6RCQZZWV9QOJwFFQ'},
#   {'label': 'CityOn', 'value': 'UCZJCKa3l5khIWKLJI2j4KzA'},
#   {'label': 'Filipe Tanus Marçal', 'value': 'UCrHD7gi1dsYJxd5mwLUBcMA'},
#   {'label': 'Kebrada Geek', 'value': 'UC5csyUXd3EC4PO56Tylhjrg'},
#   {'label': 'Sete iwnl', 'value': 'UCgjDilJmvwt2kgVTgVgxvkQ'},
#   {'label': 'Francalvaro Gamer', 'value': 'UCSbjl-r8UgyK76TEL7rPBSQ'},
#   {'label': 'PC Gamer TV', 'value': 'UCdVo3xvNeIsv_idEnsubEOw'},
#   {'label': 'Ale_Bagunçinha MTA', 'value': 'UC9c1ArBS7twtRpy_NJ_qGwA'},
#   {'label': 'Tecnologia', 'value': 'UCz1XR21d0ivMHFpe8h4alww'},
#   {'label': 'oidsystem', 'value': 'UCI7J2DPxA5PBGMaoSwq5png'},
#   {'label': 'gabriel', 'value': 'UCHTni7AM41ljKK2ypJIVTwQ'},
#   {'label': 'GxTec', 'value': 'UCEZ12_9vkxdT1BuZFqtfkfw'},
#   {'label': 'MalvinaN', 'value': 'UCIphdX9Ubx6mycasvQOwwag'},
#   {'label': 'nigeriakkj', 'value': 'UCK2tauyeJ2Zk041SdyuL5TQ'},
#   {'label': 'XboxBR', 'value': 'UCi9Uzh14BHqkN7UO_2lbrMw'},
#   {'label': 'ULI2084', 'value': 'UCchPZwAV59qmmp6tKQalL6Q'},
#   {'label': 'wzz', 'value': 'UCLXbP3xz78Yz7HW5avm4zDg'},
#   {'label': 'bruno', 'value': 'UCwsz8_u5T8yi8CahZAGHPkg'}]}
